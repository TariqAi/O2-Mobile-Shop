# %%
Image(url='https://www.gizchina.com/wp-content/uploads/images/2021/04/samrtphones.jpg', width=1000)
# Out:
# <img src="https://www.gizchina.com/wp-content/uploads/images/2021/04/samrtphones.jpg" width="1000"/>

# %% [markdown]
# ## 🔹 Import the required libraries

# %%
from IPython.display import Image

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 🔹 Load the dataset using the pandas read function

# %%
data= pd.read_csv('all_phones.csv')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  storage(GB)  video_720p  \
# 0        Li-Po        2        2016-09-01      140.0           16        True
# 1       Li-Ion        2        2016-12-01      140.0           16       False
# 2       Li-Ion        4        2017-01-01      147.0           16       False
# 3        Li-Po        4        2017-01-01      165.0           32        True
# 4       Li-Ion        4        2017-02-01      145.0           32        True
#
#    video_1080p  video_4K  video_8K  video_30fps  video_60fps  video_120fps  \
# ...

# %% [markdown]
# ## 🔹 Set the dataset information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %% [markdown]
# ## 🔹 Checking the data shape

# %%
data.shape
# Out:
# (1512, 22)

# %% [markdown]
# ## 🔹 Statistical information about the data set

# %%
data.describe()
# Out:
#             inches      battery      ram(GB)    weight(g)  storage(GB)  \
# count  1512.000000  1512.000000  1512.000000  1512.000000  1512.000000
# mean      6.422460  4389.798942     6.683862   187.636243   109.164683
# std       0.477043   784.607022     2.701433    26.200115    74.436484
# min       3.800000  1821.000000     1.000000   130.000000     1.000000
# 25%       6.300000  4000.000000     4.000000   175.000000    64.000000
# 50%       6.500000  4500.000000     8.000000   187.000000   128.000000
# 75%       6.670000  5000.000000     8.000000   197.250000   128.000000
# max      10.400000  7250.000000    24.000000   500.000000   512.000000
#
#         price(USD)
# count  1512.000000
# mean    337.847036
# std     266.740821
# min      40.000000
# 25%     179.997500
# 50%     260.000000
# 75%     400.000000
# max    2300.000000

# %% [markdown]
# ## 🔹 Checking the null values in the data

# %%
data.isna().sum()/len(data)*100
# Out:
# phone_name           0.0
# brand                0.0
# os                   0.0
# inches               0.0
# resolution           0.0
# battery              0.0
# battery_type         0.0
# ram(GB)              0.0
# announcement_date    0.0
# weight(g)            0.0
# storage(GB)          0.0
# video_720p           0.0
# video_1080p          0.0
# video_4K             0.0
# video_8K             0.0
# video_30fps          0.0
# video_60fps          0.0
# video_120fps         0.0
# video_240fps         0.0
# video_480fps         0.0
# video_960fps         0.0
# price(USD)           0.0
# dtype: float64

# %% [markdown]
# ## 🔹 Explore Data Analysis

# %%
# Checking the unique company brand names in the data
data['brand'].unique()
# Out:
# array(['Huawei', 'LG', 'Xiaomi', 'Sony', 'Oppo', 'Samsung', 'Lenovo',
#        'Apple', 'Google', 'Honor', 'Realme', 'OnePlus', 'Vivo'],
#       dtype=object)

# %%
# Which brand companies most used
data['brand'].value_counts()
# Out:
# brand
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: count, dtype: int64

# %%
data['brand'].value_counts().sort_values(ascending=False)\
.plot(kind='pie', autopct='%1.0f%%', cmap='viridis')
plt.xlabel("Brand names")
plt.ylabel("Count of value")
plt.show()

# %%
# To visualize the which batterys and rams most used

for i in data[['battery','battery_type', 'ram(GB)', 'resolution', 'os']]:
    data[i].value_counts().sort_values(ascending=False)\
    .plot(kind='bar', figsize=(10,5), color=['#008000', '#17A589', '#000080', '#F1C40F' , '#800000'])
    plt.title(f"Visualize the most used {i} in the data")
    plt.xticks(rotation=90)
    plt.xlabel({i})
    plt.ylabel("Count of values")
    plt.show()

# %%
#The price column contains the dollar currency, So we convert dollar into Jordan dinar

today_dollar_price = 0.71
data['Jod_price']= data['price(USD)'] * today_dollar_price

sum_of_prices= data.groupby(['brand'])['Jod_price'].sum().sort_values(ascending=False)
print(f'{(sum_of_prices).round(1)}')
# Out:
# brand
# Xiaomi     57404.3
# Oppo       51619.6
# Samsung    50863.7
# Vivo       40316.9
# Huawei     39288.7
# Honor      31546.3
# Realme     27021.2
# LG         14058.0
# OnePlus    14049.1
# Sony       12367.5
# Apple      10622.2
# Lenovo      7483.4
# Google      6044.6
# Name: Jod_price, dtype: float64

# %%
# Select the categorical columns in the data

for i in data.select_dtypes(include='bool'):
    values=data[i].value_counts()
    plt.figure(figsize=(8,5))
    sns.barplot(data=data, x=values.index, y=values.values)
    plt.title(f"Visualize the most used {i} in the data")
    plt.xlabel(i)
    plt.ylabel("Count of values")
    plt.show()

# %%
# Top 20 mobile brand with ram wise
brand_ram = pd.DataFrame(data.groupby(['brand'])['ram(GB)'].value_counts().sort_values())
brand_ram.head(30).unstack().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## 🟢 Observations we recevied from the above data

# %% [markdown]
# ✅ In the bar charts, we observed that Xiaomi, Oppo, and Samsung are the leading mobile selling companies.
#
# ✅ In the grouped bar charts, mobiles with 5000mAh battery capacity, Android 11 version, and Li-Po batteries are the most           demanded within their respective brands.
#
# ✅ Most brands offer mobiles capable of recording HD, FHD, 2K, and 4K videos.
#
# ✅ In the dataset, on February 11, 2020, Samsung launched 7 variants, and on March 4, 2021, Xiaomi released 6 variants.
#
# ✅ Most mobiles are sold with 8GB of RAM, and Xiaomi dominates the market, with Oppo in the second place.

# %% [markdown]
# # Regards, Tariq Ibrahim
